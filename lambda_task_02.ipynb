# %%
event={"name":"jayasri","account_number":1234566789,"credit_type":"debit","location":"non_metro","age":22,"loan":"yes","employee_type":"salaried","initial_amount":100000,"amount":94000}

def bank_details(event):
    if event["name"]=="jayasri" and event["account_number"]==1234566789:
        if event["credit_type"]=="credit":
            balance=event["amount"]+event["initial_amount"]
            if event["loan"]=="yes":
                balance=balance-1000
                if event["location"]=="metro":
                    balance=balance+2000
                    if event["age"]>25:
                        balance=balance+18000
                    elif event["age"]<25:
                        balance=balance+0
                        if  event["employee_type"]=="salaried":
                            balance=balance+0
                        elif event["employee_type"]=="individual":
                            balance=balance+1000
                        elif event["employee_type"]=="business":
                            balance=balance+500
            elif event["loan"]=="no":
                balance=balance+1000
                if event["location"]=="metro":
                    balance=balance+2000
                    if event["age"]>25:
                        balance=balance+18000
                    elif event["age"]<25:
                        balance=balance+0
                        if  event["employee_type"]=="salaried":
                            balance=balance+0
                        elif event["employee_type"]=="individual":
                            balance=balance+1000
                        elif event["employee_type"]=="business":
                            balance=balance+500
          
            elif event["loan"]=="yes":
                balance=balance-1000
                if event["location"]=="non_metro":
                    balance=balance-2000
                if event["age"]>25:
                    balance=balance+18000
                elif event["age"]<25:
                    balance=balance+0
                    if  event["employee_type"]=="salaried":
                        balance=balance+0
                    elif event["employee_type"]=="individual":
                        balance=balance+1000
                    elif event["employee_type"]=="business":
                        balance=balance+500 
                        
            elif event["loan"]=="no":
                balance=balance+1000
                if event["location"]=="non_metro":
                    balance=balance-2000
                    if event["age"]>25:
                        balance=balance+18000
                    elif event["age"]<25:
                        balance=balance+0
                        if  event["employee_type"]=="salaried":
                            balance=balance+0
                        elif event["employee_type"]=="individual":
                            balance=balance+1000
                        elif event["employee_type"]=="business":
                            balance=balance+500    

        elif event["credit_type"]=="debit":
                balance=event["initial_amount"]-event["amount"]
                if event["loan"]=="yes":
                    balance=balance-1000
                    if event["location"]=="metro":
                        balance=balance+2000
                        if event["age"]>25:
                            balance=balance+18000
                        elif event["age"]<25:
                            balance=balance+0
                            if  event["employee_type"]=="salaried":
                                balance=balance+0
                            elif event["employee_type"]=="individual":
                                balance=balance+1000
                            elif event["employee_type"]=="business":
                                balance=balance+500
                elif event["loan"]=="no":
                    balance=balance+1000
                    if event["location"]=="metro":
                        balance=balance+2000
                        if event["age"]>25:
                            balance=balance+18000
                        elif event["age"]<25:
                            balance=balance+0
                            if  event["employee_type"]=="salaried":
                                balance=balance+0
                            elif event["employee_type"]=="individual":
                                balance=balance+1000
                            elif event["employee_type"]=="business":
                                balance=balance+500

                elif event["loan"]=="yes":
                    balance=balance-1000
                    if event["location"]=="non_metro":
                        balance=balance-2000
                    if event["age"]>25:
                        balance=balance+18000
                    elif event["age"]<25:
                        balance=balance+0
                        if  event["employee_type"]=="salaried":
                            balance=balance+0
                        elif event["employee_type"]=="individual":
                            balance=balance+1000
                        elif event["employee_type"]=="business":
                            balance=balance+500 

                elif event["loan"]=="no":
                    balance=balance+1000
                    if event["location"]=="non_metro":
                        balance=balance-2000
                        if event["age"]>25:
                            balance=balance+18000
                        elif event["age"]<25:
                            balance=balance+0
                            if  event["employee_type"]=="salaried":
                                balance=balance+0
                            elif event["employee_type"]=="individual":
                                balance=balance+1000
                            elif event["employee_type"]=="business":
                                balance=balance+500    
        return(balance)

# %%
bank_details(event)
# Out:
# 5000

# %%
from flask import Flask,jsonify,request
app = Flask(__name__)
@app.route('/',methods = ['GET','PsOST'])
def home():
    if (request.method == 'GET'):
        data = "jayasri first app building"
        price = "50k"
        
        return jsonify({'data':data,'price':price})
if __name__=='__main__':
    app.run(debug = False)

# %%
event={ "name":"jayasri","account_number":1234566789,"type_of_credit":"debit","loan":"yes","location":"non_metro","age":27,"employement_type":"individual", "initial_amount":100000,"amount":30000}

def bank_details(event):
   
    if event['name']=="jayasri" and event["account_number"]==1234566789:
        
        if event["type_of_credit"]=="credit":
            balance=event["amount"]+event["initial_amount"]
        elif event["type_of_credit"]=="debit":
            balance=event["amount"]-event["initial_amount"]
            
        if event["loan"]=="yes":
            balance=event["amount"]-1000
        elif event["loan"]=="no":
              balance=event["amount"]+1000
                
        if event["age"]>25:
            balance=event['amount']+18000
        elif event["age"]<25:
            balance=event["amount"]+0
            
        if event["location"]=="metro":
            balance=event["amount"]+2000
        elif event["location"]=="non_metro":
            balance=event["amount"]-2000
            
        if event["employement_type"]=="salaried":
            balance=balance+0
        if event["employement_type"]=="individual":
            balance=event["amount"]+1000
        elif event["employement_type"]=="business":
            balance=event["amount"]+500
                       
    return(balance)

# %%
bank_details(event)
# Out:
# 31000

# %%
event={"name":"jayasri","account_number":1234566789,"credit_type":"debit","location":"metro","age":27,"loan":"no","employee_type":"salaried","amount":3000}

def bank_details(event):
    initial_amount=10000
    if event["name"]=="jayasri" and event["account_number"]==1234566789:
        if event["credit_type"]=="credit":
            balance=event["amount"]+event[initial_amount]
            if event["location"]=="metro":
                balance=balance+2000
                if event["loan"]=="yes":
                    balance=balance-1000
                    if event["age"]>25:
                        balance=balance+18000
                    elif event["age"]<25:
                        balance=balance+0
                        if event["employee_type"]=="salaried":
                            balance=balance+0
                        elif event["employee_type"]=="individual":
                            balance=balance+1000
                        elif event["employee_type"]=="business":
                            balance=balance+500
    return(balance)

# %%
bank_details(event)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 bank_details(event)
#
# Cell In[51], line 22, in bank_details(event)
#      20                     elif event["employee_type"]=="business":
#      21                         balance=balance+500
# ---> 22 return(balance)
#
# UnboundLocalError: local variable 'balance' referenced before assignment

# %%
event={"name":"jayasri","account_number":1234566789,"credit_type":"debit","location":"non_metro","age":22,"loan":"yes","employee_type":"salaried","initial_amount":100000,"amount":94000}

def bank_details(event):
    if event["name"]=="jayasri" and event["account_number"]==1234566789:
        if event["credit_type"]=="credit":
            balance=event["amount"]+event["initial_amount"]
            if event["location"]=="metro":
                balance=balance+2000
                if event["loan"]=="yes":
                    balance=balance-1000
                    if event["age"]>25:
                        balance=balance+18000
                    elif event["age"]<25:
                        balance=balance+0
                        if  event["employee_type"]=="salaried":
                            balance=balance+0
                        elif event["employee_type"]=="individual":
                            balance=balance+1000
                        elif event["employee_type"]=="business":
                            balance=balance+500
                                
           
            elif event["location"]=="non_metro":
                    balance=balance+2000
                    if event["loan"]=="yes":
                        balance=balance+1000
                            if event["age"]>25:
                                balance=balance+18000
                            elif event["age"]<25:
                                balance=balance+0
                                if  event["employee_type"]=="salaried":
                                    balance=balance+0
                                elif event["employee_type"]=="individual":
                                    balance=balance+1000
                                elif event["employee_type"]=="business":
                                    balance=balance+500

            
                elif event["location"]=="metro":
                    balance=balance-2000
                    if event["loan"]=="no":
                        balance=balance-1000
                        if event["age"]>25:
                            balance=balance+18000
                        elif event["age"]<25:
                            balance=balance+0
                            if  event["employee_type"]=="salaried":
                                balance=balance+0
                            elif event["employee_type"]=="individual":
                                balance=balance+1000
                            elif event["employee_type"]=="business":
                                balance=balance+500 

           
                if event["location"]=="non_metro":
                    balance=balance-2000
                     elif event["loan"]=="no":
                        balance=balance+1000
                        if event["age"]>25:
                            balance=balance+18000
                        elif event["age"]<25:
                            balance=balance+0
                            if  event["employee_type"]=="salaried":
                                balance=balance+0
                            elif event["employee_type"]=="individual":
                                balance=balance+1000
                            elif event["employee_type"]=="business":
                                balance=balance+500    

       
        return(balance)
# Out:
#   Cell In[91], line 8
#     if event["location"]=="metro":
#     ^
# IndentationError: unexpected indent

# %%
 elif event["credit_type"]=="debit":
                balance=event["initial_amount"]-event["amount"]
                if event["loan"]=="yes":
                    balance=balance-1000
                    if event["location"]=="metro":
                        balance=balance+2000
                        if event["age"]>25:
                            balance=balance+18000
                        elif event["age"]<25:
                            balance=balance+0
                            if  event["employee_type"]=="salaried":
                                balance=balance+0
                            elif event["employee_type"]=="individual":
                                balance=balance+1000
                            elif event["employee_type"]=="business":
                                balance=balance+500
                elif event["loan"]=="no":
                    balance=balance+1000
                    if event["location"]=="metro":
                        balance=balance+2000
                        if event["age"]>25:
                            balance=balance+18000
                        elif event["age"]<25:
                            balance=balance+0
                            if  event["employee_type"]=="salaried":
                                balance=balance+0
                            elif event["employee_type"]=="individual":
                                balance=balance+1000
                            elif event["employee_type"]=="business":
                                balance=balance+500

                elif event["loan"]=="yes":
                    balance=balance-1000
                    if event["location"]=="non_metro":
                        balance=balance-2000
                    if event["age"]>25:
                        balance=balance+18000
                    elif event["age"]<25:
                        balance=balance+0
                        if  event["employee_type"]=="salaried":
                            balance=balance+0
                        elif event["employee_type"]=="individual":
                            balance=balance+1000
                        elif event["employee_type"]=="business":
                            balance=balance+500 

                elif event["loan"]=="no":
                    balance=balance+1000
                    if event["location"]=="non_metro":
                        balance=balance-2000
                        if event["age"]>25:
                            balance=balance+18000
                        elif event["age"]<25:
                            balance=balance+0
                            if  event["employee_type"]=="salaried":
                                balance=balance+0
                            elif event["employee_type"]=="individual":
                                balance=balance+1000
                            elif event["employee_type"]=="business":
                                balance=balance+500
