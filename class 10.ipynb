# %%
import pandas as pd
df=pd.read_excel(r"C:\Jayasri\class - 10\friends names.xlsx",header=None)
df
# Out:
#                  0              1
# 0   Friend’s names        Quality
# 1          Rohitha       innocent
# 2           Geetha            Joy
# 3          Hareesh    intelligent
# 4          Supraja    intelligent
# 5              Sai          anger
# 6          Lakshmi  silent killer
# 7            Divya          funny
# 8            Krupa     brave girl
# 9           Rajini          funny
# 10          Swarna    intelligent
# 11         mounika          funny
# 12          bhanu     intelligent
# 13    naga lakshmi          funny
# 14          anusha          funny

# %%
df[df["Quality"]=="intelligent"]
# Out:
#    Friend’s names      Quality
# 2         Hareesh  intelligent
# 3         Supraja  intelligent
# 9          Swarna  intelligent
# 11         bhanu   intelligent

# %%
df[df["Quality"]=="funny"]
# Out:
#    Friend’s names Quality
# 6           Divya   funny
# 8          Rajini   funny
# 10        mounika   funny
# 12   naga lakshmi   funny
# 13         anusha   funny

# %%
import pandas as pd
df=pd.read_excel(r"C:\Jayasri\class - 10\family members.xlsx")
df
# Out:
#     Family Members        Relation
# 0     JanardhnaRao         Parents
# 1          Lakshmi         Parents
# 2          Mounika          sister
# 3   Devivaraprasad         brother
# 4          Jayasri          myself
# 5        Basavaiah     grandfather
# 6             Rama           aunty
# 7       Ashokkumar  brother-in-law
# 8           Rajini   sister-in-law
# 9           rakesh         brother
# 10      rajasekhar         brother
# 11    bala krishna         Parents
# 12           bhanu   sister-in-law
# 13        rangamma   sister-in-law
# 14          parvin          sister
# 15         shabana          sister

# %%
df.columns
# Out:
# Index(['Family Members', 'Relation'], dtype='object')

# %%
df_p=df[df["Relation"]=="Parents"]
df_p
# Out:
#    Family Members Relation
# 0    JanardhnaRao  Parents
# 1         Lakshmi  Parents
# 11   bala krishna  Parents

# %%
#Q3> create a dataframe which not contains your parents list.
df_not=df[df["Relation"]!="Parents"]

# %%
df_not
# Out:
#     Family Members        Relation
# 2          Mounika          sister
# 3   Devivaraprasad         brother
# 4          Jayasri          myself
# 5        Basavaiah     grandfather
# 6             Rama           aunty
# 7       Ashokkumar  brother-in-law
# 8           Rajini   sister-in-law
# 9           rakesh         brother
# 10      rajasekhar         brother
# 12           bhanu   sister-in-law
# 13        rangamma   sister-in-law
# 14          parvin          sister
# 15         shabana          sister

# %%
# create a dataframe which not contains your brothers list.
df[df["Relation"]!="brother"]
# Out:
#    Family Members        Relation
# 0    JanardhnaRao         Parents
# 1         Lakshmi         Parents
# 2         Mounika          sister
# 4         Jayasri          myself
# 5       Basavaiah     grandfather
# 6            Rama           aunty
# 7      Ashokkumar  brother-in-law
# 8          Rajini   sister-in-law
# 11   bala krishna         Parents
# 12          bhanu   sister-in-law
# 13       rangamma   sister-in-law
# 14         parvin          sister
# 15        shabana          sister

# %%
#Q5> create a dataframe which contains your brothers list and parents list.
lst=["brother","sister"]
df[~df.Relation.isin(lst)]
# Out:
#    Family Members        Relation
# 0    JanardhnaRao         Parents
# 1         Lakshmi         Parents
# 4         Jayasri          myself
# 5       Basavaiah     grandfather
# 6            Rama           aunty
# 7      Ashokkumar  brother-in-law
# 8          Rajini   sister-in-law
# 11   bala krishna         Parents
# 12          bhanu   sister-in-law
# 13       rangamma   sister-in-law

# %%
lst=["brother","sister"]
df[df.Relation.isin(lst)]
# Out:
#     Family Members Relation
# 2          Mounika   sister
# 3   Devivaraprasad  brother
# 9           rakesh  brother
# 10      rajasekhar  brother
# 14          parvin   sister
# 15         shabana   sister

# %%
lst=["brother","sister"]
df[~df.Relation.isin(lst)]
# Out:
#    Family Members        Relation
# 0    JanardhnaRao         Parents
# 1         Lakshmi         Parents
# 4         Jayasri          myself
# 5       Basavaiah     grandfather
# 6            Rama           aunty
# 7      Ashokkumar  brother-in-law
# 8          Rajini   sister-in-law
# 11   bala krishna         Parents
# 12          bhanu   sister-in-law
# 13       rangamma   sister-in-law

# %%
import pandas as pd
df=pd.read_excel(r"C:\Jayasri\class - 10\family members.xlsx")
df
# Out:
#     Family Members        Relation
# 0     JanardhnaRao          Father
# 1          Lakshmi          mother
# 2          Mounika          sister
# 3   Devivaraprasad         brother
# 4          Jayasri          myself
# 5        Basavaiah     grandfather
# 6             Rama           aunty
# 7       Ashokkumar  brother-in-law
# 8           Rajini   sister-in-law
# 9           rakesh         brother
# 10      rajasekhar         brother
# 11    bala krishna         brother
# 12           bhanu   sister-in-law
# 13        rangamma   sister-in-law
# 14          parvin          sister
# 15         shabana          sister

# %%
import pandas as pd
df=pd.read_excel(r"C:\Jayasri\class - 10\veg food.xlsx")
df
# Out:
#       VegFoodName   Taste
# 0          potato     fry
# 1    ladies finger   soup
# 2         brinjal   curry
# 3           carrot    fry
# 4          onions   curry
# 5           tomato   soup
# 6           sambar   soup
# 7          cabage   curry
# 8      califlower   curry
# 9   bitter guared     fry
# 10            dhal   soup

# %%
df[df["Taste"]=="fry"]
# Out:
#      VegFoodName  Taste
# 0         potato    fry
# 3          carrot   fry
# 9  bitter guared    fry

# %%
df[df["Taste"]=="curry"]
# Out:
#   VegFoodName   Taste
# 2     brinjal   curry
# 4      onions   curry
# 7      cabage   curry
# 8  califlower   curry

# %%
df[df["Taste"]=="soup"]
# Out:
#      VegFoodName  Taste
# 1   ladies finger  soup
# 5          tomato  soup
# 6          sambar  soup
# 10           dhal  soup

# %%
df.columns


#df[df["Taste"]
# Out:
# Index(['VegFoodName ', 'Taste'], dtype='object')

# %%
lst1=["soup","fry"]
df[df.Taste.isin(lst1)]
# Out:
#       VegFoodName  Taste
# 0          potato    fry
# 1    ladies finger  soup
# 3           carrot   fry
# 5           tomato  soup
# 6           sambar  soup
# 9   bitter guared    fry
# 10            dhal  soup

# %%
lst1=["soup","fry"]
df[~df.Taste.isin(lst1)]
# Out:
#   VegFoodName   Taste
# 2     brinjal   curry
# 4      onions   curry
# 7      cabage   curry
# 8  califlower   curry

# %%
df[(df["Taste"]=="soup") | (df["Taste"]=="fry")]
# Out:
#       VegFoodName  Taste
# 0          potato    fry
# 1    ladies finger  soup
# 3           carrot   fry
# 5           tomato  soup
# 6           sambar  soup
# 9   bitter guared    fry
# 10            dhal  soup

# %%
lst2=["soup","fry"]
df[~df.Taste.isin(lst2)]
# Out:
#   VegFoodName   Taste
# 2     brinjal   curry
# 4      onions   curry
# 7      cabage   curry
# 8  califlower   curry

# %%
df[df["Taste"]!="curry"]
# Out:
#       VegFoodName  Taste
# 0          potato    fry
# 1    ladies finger  soup
# 3           carrot   fry
# 5           tomato  soup
# 6           sambar  soup
# 9   bitter guared    fry
# 10            dhal  soup

# %%
import pandas as pd
df=pd.read_excel(r"C:\Jayasri\class - 10\non veg.xlsx")
df
# Out:
#      non-veg-items  taste
# 0          chicken    hot
# 1             fish    NaN
# 2  chicken briyani    hot
# 3           mutton   hot
# 4   mutton briyani    NaN
# 5           fronce   hot
# 6        ice-cream   cool
# 7            drink   cool
# 8          chicken    fry
# 9           mutton    fry

# %%
df[df["non-veg-items"]=="chicken"]
# Out:
#   non-veg-items taste
# 0       chicken   hot
# 8       chicken   fry

# %%
df[df["non-veg-items"]=="mutton"]
# Out:
#   non-veg-items taste
# 3        mutton  hot
# 9        mutton   fry

# %%
df[df["taste"]=="fry"]
# Out:
#   non-veg-items taste
# 8       chicken   fry
# 9        mutton   fry

# %%
lst=["fry","chicken"]
df[df.taste.isin(lst)]
# Out:
#   non-veg-items taste
# 8       chicken   fry
# 9        mutton   fry

# %%
lst=["fry","chicken"]
df[~df.taste.isin(lst)]
# Out:
#      non-veg-items  taste
# 0          chicken    hot
# 1             fish    NaN
# 2  chicken briyani    hot
# 3           mutton   hot
# 4   mutton briyani    NaN
# 5           fronce   hot
# 6        ice-cream   cool
# 7            drink   cool

# %%
df[(df["non-veg-items"]=="chicken") |  (df["taste"]=="fry")]
# Out:
#   non-veg-items taste
# 0       chicken   hot
# 8       chicken   fry
# 9        mutton   fry

# %%
df[(df["non-veg-items"]=="mutton") |  (df["taste"]=="fry")]
# Out:
#   non-veg-items taste
# 3        mutton  hot
# 8       chicken   fry
# 9        mutton   fry

# %%
import pandas as pd
df=pd.read_excel(r"C:\Jayasri\class - 10\month names.xlsx")
df
# Out:
#    MonthName          Season
# 0     january         winter
# 1    february         winter
# 2       march         summer
# 3       april         summer
# 4         may         summer
# 5        june  rainey season
# 6        july  rainey season
# 7      august  rainey season
# 8   september  rainey season
# 9    octomber  rainey season
# 10   november         winter
# 11   december         winter

# %%
df[df["Season"]=="summer"]
# Out:
#   MonthName   Season
# 2      march  summer
# 3      april  summer
# 4        may  summer

# %%
df[df["Season"]=="winter"]
# Out:
#    MonthName   Season
# 0     january  winter
# 1    february  winter
# 10   november  winter
# 11   december  winter

# %%
df[df["Season"]=="rainey season"]
# Out:
#   MonthName          Season
# 5       june  rainey season
# 6       july  rainey season
# 7     august  rainey season
# 8  september  rainey season
# 9   octomber  rainey season

# %%
df[(df["Season"]=="summer") | (df["Season"]=="winter")]
# Out:
#    MonthName   Season
# 0     january  winter
# 1    february  winter
# 2       march  summer
# 3       april  summer
# 4         may  summer
# 10   november  winter
# 11   december  winter

# %%
lst=["summer","rainey season"]
df[~df.Season.isin(lst)]
# Out:
#    MonthName   Season
# 0     january  winter
# 1    february  winter
# 10   november  winter
# 11   december  winter

# %%
df[(df["Season"]=="winter") | (df["Season"]=="rainey season")]
# Out:
#    MonthName          Season
# 0     january         winter
# 1    february         winter
# 5        june  rainey season
# 6        july  rainey season
# 7      august  rainey season
# 8   september  rainey season
# 9    octomber  rainey season
# 10   november         winter
# 11   december         winter

# %%
import pandas as pd
df=pd.read_excel(r"C:\Jayasri\class - 10\new_colours_names.xlsx")
df
# Out:
#   flower names english     hindi   telugu
# 0         rose     Red      lall    erupu
# 1      jasmine    Blue    neelam   bulugu
# 2        lilly   white     safed   telupu
# 3     hibiscus   Black      kala   nalupu
# 4     marigold  Yellow      pela   pasupu
# 5     red rose  Orange  lal rose  narenja
# 6         rose     Red      lall    erupu
# 7        lilly   white     safed   telupu
# 8    pink rose    pink     gulab  gulabii

# %%
df.columns
# Out:
# Index(['flower names', 'english', 'hindi', 'telugu'], dtype='object')

# %%
df=df[["english"]]
df
# Out:
#   english
# 0     Red
# 1    Blue
# 2   white
# 3   Black
# 4  Yellow
# 5  Orange
# 6     Red
# 7   white
# 8    pink

# %%
#Q1>create a dataframe which contains only red colour flower list
df_red=df[df["english"]=="Red"]
df_red
# Out:
#   english
# 0     Red
# 6     Red

# %%
df=df[df.english=="white"]
df
# Out:
#   english
# 2   white
# 7   white

# %%
Q2>create a dataframe which contains only white colour flower list

# %%
lst1=["Red","pink"]
df[df["english"].isin(lst1)]
# Out:
#   english
# 0     Red
# 6     Red
# 8    pink

# %%
df=df[["english"]]
df
# Out:
#   english
# 0     Red
# 1    Blue
# 2   white
# 3   Black
# 4  Yellow
# 5  Orange
# 6     Red
# 7   white
# 8    pink

# %%
#Q5>create a dataframe which not contains red and white colour list
lst=["Red","white"]
df[~df.english.isin(lst)]
# Out:
#   english
# 1    Blue
# 3   Black
# 4  Yellow
# 5  Orange
# 8    pink

# %%
#Q6>create a dataframe which contains either red or pink colour list

# %%
df=df[df.english=="white"]
df
# Out:
#   flower names english  hindi  telugu
# 2        lilly   white  safed  telupu
# 7        lilly   white  safed  telupu

# %%
df["english"]
# Out:
# 8    pink
# Name: english, dtype: object
